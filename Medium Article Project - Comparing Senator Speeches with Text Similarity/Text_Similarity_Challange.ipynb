# %%
df1 = open("105-abraham-mi.txt").read()
df2 = open("105-akaka-hi.txt").read()

# %%
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re
from nltk.tokenize import word_tokenize
import pandas as pd
#from nltk.stem import WordNetLemmatizer

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def text_preprocesser(text):
    text= re.sub(r'\W',' ', text)
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token not in stopwords.words('english')]
    tokens = [word for word in tokens if len(word)>=3]
    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

# %%
text_preprocesser(df1)
text_preprocesser(df2)
# Out:
# 'doc docno 105 akaka 19981021 docno text akaka president pleased senate passed 4110 veterans programs enhancement act 1998 measure strives improve services benefits provided nation veterans amending several health education housing benefits programs within department veterans affairs especially pleased measure contains two provisions working section 603 bill extend eligibility members national guard reserve department veterans affairs home loan guaranty program provision ensure men women selected reserve continue eligible program september 2003 current law authorization program scheduled expire october 1999 author legislation 1992 extended eligibility guaranteed home loans national guard reserve members complete six years service pleased participation program members selected reserve home loan guaranty program guard reserve members provided many individuals families needed opportunity obtain mortgage order purchase home many first time home loan guaranty program beneficial members selected reserve also contributes financial viability home loan guaranty program since origination fees paid reservists offset cost additional loan guarantees gratified home loan program continue made available members national guard reserves served country also pleased inclusion section 706 4110 provision would prohibit secretary veterans affairs establishing collecting parking fees spark matsunaga department veterans affairs medical regional office center honolulu hawaii current law required charge users employees park facilities built special revolving funds hawaii parking structure located grounds tripler army medical hospital shared department defense joint dod parking facility would result administrative nightmare parking fees required assessed medical employees visitors dod personnel visitors furthermore costs administering parking fees far outweigh revenues would generated assessment nominal parking charges waiver parking fees parking structure tripler army medical center ensure visitors employees enjoy free equal access facilities text doc doc docno 105 akaka 19981007 docno text akaka president last year house senate working legislation would reauthorize endangered species act 1973 senate environment public works committee reported legislation offered colleague idaho senator kempthorne would modify act significant ways although unlikely take bill short time remaining would like make observations endangered species act meant hawaii home endangered species state territory within united states president legislators guardians nation rich natural inheritance capacity afford squander ecological legacy leave children surely part concern rare species ecosystems simple realization gone would failed stewardship responsibility hawaii poised brink irreversible ecological change important wise stewardship decisions rendered preserve unique tropical ecosystem term ecosystem become political buzzword adequately described delicate checks balances make natural world basis hawaii natural system begins list threatened plants animals unique origin islands millions years lava welling earth mantle cooled upon ocean floor gradually forming hawaiian islands one one process ongoing even today one island moves away influence hot spot middle pacific another island born island peak volcanic mountain base hidden far surface ocean types birds insects plants able colonize remote islands evolved scores even hundreds unique species islands sheltered large land mammals reptiles creatures gradually lost natural defenses predators endangered species act critical unique insular ecosystem 126 total species listed fish wildlife service protection esa although islands represent two tenths one percent total land area hawaii home rare endangered species state territory addition three fourths nation extinct plants birds existed hawaii hawaii astounding 363 listed endangered species california 223 listed species rivals hawaii number listed endangered species pacific islands including  ...

# %%
# !pip install WordCloud
from wordcloud import WordCloud
# Out:
# Requirement already satisfied: WordCloud in c:\users\yigit\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: pillow in c:\users\yigit\anaconda3\lib\site-packages (from WordCloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\yigit\anaconda3\lib\site-packages (from WordCloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\yigit\anaconda3\lib\site-packages (from WordCloud) (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\yigit\anaconda3\lib\site-packages (from matplotlib->WordCloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\yigit\anaconda3\lib\site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yigit\anaconda3\lib\site-packages (from matplotlib->WordCloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\yigit\anaconda3\lib\site-packages (from matplotlib->WordCloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yigit\anaconda3\lib\site-packages (from matplotlib->WordCloud) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yigit\anaconda3\lib\site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\yigit\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)

# %%
docs = [df1, df2]

# %%
tfidf_vectorizer = TfidfVectorizer(preprocessor = text_preprocesser, min_df =2 )

# %%
tfidf_vectorizer
# Out:
# TfidfVectorizer(min_df=2,
#                 preprocessor=<function text_preprocesser at 0x000002278AFD6940>)

# %%
tfidf = tfidf_vectorizer.fit_transform(docs)

# %%
df

# %%
df= pd.DataFrame(tfidf.toarray().transpose(), index=tfidf_vectorizer.get_feature_names())
df.columns = ['Abraham', 'Akaka']
# Out:
# C:\Users\YIGIT\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
df
# Out:
#            Abraham     Akaka
# 000       0.060004  0.042367
# 100       0.012458  0.014122
# 100th     0.000415  0.003531
# 104       0.000415  0.001177
# 104th     0.001661  0.005884
# ...            ...       ...
# young     0.012873  0.020006
# youth     0.003737  0.011769
# youthful  0.000415  0.002354
# zones     0.001246  0.002354
# zoo       0.000415  0.001177
#
# [4541 rows x 2 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
for i in range(1, 3):
    globals()["txt" + str(i)] =df[df.columns[i-1]].values.reshape(1, -1)

# %%
print("Similarity txt1 and txt2:", cosine_similarity(txt1, txt2))
# Out:
# Similarity txt1 and txt2: [[0.77729596]]
